# %%
import os
import numpy as np
import pandas as pd
from celery import shared_task
from django.conf import settings
from django.utils import timezone
from main.models import Record
import pprint
from predict.settings import DATASET_DIR

# %%
class States:
    """ A Collection of all States """
    NORMAL = 'normal'
    ALMOST_FLOODED = 'almost_flooded'
    FLOODED = 'flooded'

# %%
def get_state(value):
    """ get the state for which value is in """
    norm_value = value/settings.DRAIN_HEIGHT
    if norm_value < 0.75:
        return States.NORMAL
    elif 0.75 < norm_value < 0.98:
        return States.ALMOST_FLOODED
    else:
        return States.FLOODED

# %%
def min_max_scaler(X, max_height):
    """ Return min-max scaler for the dataframe """
    X_std = (X - X.min(axis=0)) / (max_height - X.min(axis=0))
    return X_std * (1 -0) + 0

# %%
max_height = settings.DRAIN_HEIGHT

# %%
# Generate a Numpy Array of Records
water_level_entries = np.array(Record.objects.values_list('water_level', flat=True))

# %%
# data = pd.DataFrame({'WaterLevel': water_level_entries})
data = "data1"
data = pd.read_csv(os.path.join(DATASET_DIR, f"{data}.csv"))

# %%
data
# Out:
#                     date  Rainfall   Dam cap  WaterLevel  State
# 0    1957-01-02 00:00:00      17.2  2763.966   32.516000      0
# 1    1957-04-02 01:00:00     477.1  2763.966   32.616000      0
# 2    1957-08-02 02:00:00    2107.4  2763.966   32.716000   3513
# 3    1957-12-02 03:00:00     501.5  2763.966   32.816000      0
# 4    1958-01-02 04:00:00      23.7  2763.966   32.916000      0
# ..                   ...       ...       ...         ...    ...
# 227  2012-12-11 11:00:00     431.8  2171.387   29.035649      0
# 228  2013-01-11 12:00:00      14.9  2900.232   29.000000      0
# 229  2013-04-11 13:00:00     364.5  3346.624   29.000000      0
# 230  2013-08-11 14:00:00    2164.8  3346.624   29.000000  11087
# 231  2013-12-11 15:00:00     502.1  3346.624   29.000000      0
#
# [232 rows x 5 columns]

# %% [markdown]
# ### Initialize the necessary Variables

# %%
# Normalize Water Level data using MinMax Algorithm
data["WaterLevel"] = min_max_scaler(data["WaterLevel"].values, 34.5)

# %%
criteria = [
        data['WaterLevel'].le(0.55), 
        data['WaterLevel'].between(0.55, 0.80), 
        data['WaterLevel'].between(0.80, 0.98), 
        data['WaterLevel'].ge(0.98)]

# %%
# States can be Low, Normal, Almost Flooded and Flooded
states = {"L": "low", "N": "normal", "A": "almost_flooded", "F": "flooded"}
data['state'] = np.select(criteria, list(states.keys()), "N")
data["next_state"] = data["state"].shift()
data["next_next_state"] = data["next_state"].shift()

# %%
data
# Out:
#                     date  Rainfall   Dam cap  WaterLevel  State state  \
# 0    1957-01-02 00:00:00      17.2  2763.966    0.639273      0     N
# 1    1957-04-02 01:00:00     477.1  2763.966    0.657455      0     N
# 2    1957-08-02 02:00:00    2107.4  2763.966    0.675636   3513     N
# 3    1957-12-02 03:00:00     501.5  2763.966    0.693818      0     N
# 4    1958-01-02 04:00:00      23.7  2763.966    0.712000      0     N
# ..                   ...       ...       ...         ...    ...   ...
# 227  2012-12-11 11:00:00     431.8  2171.387    0.006482      0     L
# 228  2013-01-11 12:00:00      14.9  2900.232    0.000000      0     L
# 229  2013-04-11 13:00:00     364.5  3346.624    0.000000      0     L
# 230  2013-08-11 14:00:00    2164.8  3346.624    0.000000  11087     L
# 231  2013-12-11 15:00:00     502.1  3346.624    0.000000      0     L
#
#     next_state next_next_state
# 0          NaN             NaN
# 1            N             NaN
# 2            N               N
# 3            N               N
# 4            N               N
# ..         ...             ...
# 227          L               L
# 228          L               L
# 229          L               L
# 230          L               L
# 231          L               L
#
# [232 rows x 8 columns]

# %%
prob_state = np.array([])
for i in states.keys():
    prob_state = np.append(prob_state, [data.loc[data['state'] == i].shape[0],])

# %%
prob = prob_state/prob_state.sum()

# %%
prob
# Out:
# array([0.37931034, 0.20689655, 0.1637931 , 0.25      ])

# %%
next_state_probs = {k: states.copy() for k in states.keys()}

# %%
next_state_probs
# Out:
# {'L': {'L': 87, 'N': 1, 'A': 0, 'F': 0},
#  'N': {'L': 0, 'N': 46, 'A': 1, 'F': 0},
#  'A': {'L': 0, 'N': 1, 'A': 36, 'F': 1},
#  'F': {'L': 0, 'N': 0, 'A': 1, 'F': 57}}

# %%
# Check for transitions between states and store count
for i in states:
    for j in states:
        next_state_probs[i][j] = data[
                (data["state"] == i) & (data["next_state"] == j)].shape[0]

# %%
pd.DataFrame(next_state_probs)
# Out:
#     L   N   A   F
# L  87   0   0   0
# N   1  46   1   0
# A   0   1  36   1
# F   0   0   1  57

# %%
# Calculate the Probability of Transition based on data from transitions
df = pd.DataFrame(next_state_probs)
for i in range(df.shape[0]):
    df.iloc[i] = df.iloc[i]/df.iloc[i].sum()
print(df.values)
# Out:
# [[1.         0.         0.         0.        ]
#  [0.02083333 0.95833333 0.02083333 0.        ]
#  [0.         0.02631579 0.94736842 0.02631579]
#  [0.         0.         0.01724138 0.98275862]]

# %%
next_next_state_prob = {x: {k: states.copy() for k in states.keys()} for x in states.keys()}

# %%
pprint.PrettyPrinter(indent=2).pprint(next_next_state_prob)
# Out:
# { 'A': { 'A': {'A': 34, 'F': 1, 'L': 0, 'N': 1},
#          'F': {'A': 0, 'F': 1, 'L': 0, 'N': 0},
#          'L': {'A': 0, 'F': 0, 'L': 0, 'N': 0},
#          'N': {'A': 0, 'F': 0, 'L': 0, 'N': 1}},
#   'F': { 'A': {'A': 1, 'F': 0, 'L': 0, 'N': 0},
#          'F': {'A': 1, 'F': 56, 'L': 0, 'N': 0},
#          'L': {'A': 0, 'F': 0, 'L': 0, 'N': 0},
#          'N': {'A': 0, 'F': 0, 'L': 0, 'N': 0}},
#   'L': { 'A': {'A': 0, 'F': 0, 'L': 0, 'N': 0},
#          'F': {'A': 0, 'F': 0, 'L': 0, 'N': 0},
#          'L': {'A': 0, 'F': 0, 'L': 86, 'N': 1},
#          'N': {'A': 0, 'F': 0, 'L': 0, 'N': 1}},
#   'N': { 'A': {'A': 1, 'F': 0, 'L': 0, 'N': 0},
#          'F': {'A': 0, 'F': 0, 'L': 0, 'N': 0},
#          'L': {'A': 0, 'F': 0, 'L': 0, 'N': 0},
#          'N': {'A': 1, 'F': 0, 'L': 0, 'N': 44}}}

# %%
for i in states:
    for j in states:
        for k in states:
            next_next_state_prob[i][j][k] = data[
                (data["state"] == i) & (data["next_state"] == j) & (data["next_next_state"] == k)
            ].shape[0]

# %%
pd.DataFrame(next_next_state_prob)
# Out:
#                                    L                                  N  \
# L  {'L': 86, 'N': 1, 'A': 0, 'F': 0}   {'L': 0, 'N': 0, 'A': 0, 'F': 0}
# N   {'L': 0, 'N': 1, 'A': 0, 'F': 0}  {'L': 0, 'N': 44, 'A': 1, 'F': 0}
# A   {'L': 0, 'N': 0, 'A': 0, 'F': 0}   {'L': 0, 'N': 0, 'A': 1, 'F': 0}
# F   {'L': 0, 'N': 0, 'A': 0, 'F': 0}   {'L': 0, 'N': 0, 'A': 0, 'F': 0}
#
#                                    A                                  F
# L   {'L': 0, 'N': 0, 'A': 0, 'F': 0}   {'L': 0, 'N': 0, 'A': 0, 'F': 0}
# N   {'L': 0, 'N': 1, 'A': 0, 'F': 0}   {'L': 0, 'N': 0, 'A': 0, 'F': 0}
# A  {'L': 0, 'N': 1, 'A': 34, 'F': 1}   {'L': 0, 'N': 0, 'A': 1, 'F': 0}
# F   {'L': 0, 'N': 0, 'A': 0, 'F': 1}  {'L': 0, 'N': 0, 'A': 1, 'F': 56}

# %%
data
# Out:
#                     date  Rainfall   Dam cap  WaterLevel  State state  \
# 0    1957-01-02 00:00:00      17.2  2763.966    0.639273      0     N
# 1    1957-04-02 01:00:00     477.1  2763.966    0.657455      0     N
# 2    1957-08-02 02:00:00    2107.4  2763.966    0.675636   3513     N
# 3    1957-12-02 03:00:00     501.5  2763.966    0.693818      0     N
# 4    1958-01-02 04:00:00      23.7  2763.966    0.712000      0     N
# ..                   ...       ...       ...         ...    ...   ...
# 227  2012-12-11 11:00:00     431.8  2171.387    0.006482      0     L
# 228  2013-01-11 12:00:00      14.9  2900.232    0.000000      0     L
# 229  2013-04-11 13:00:00     364.5  3346.624    0.000000      0     L
# 230  2013-08-11 14:00:00    2164.8  3346.624    0.000000  11087     L
# 231  2013-12-11 15:00:00     502.1  3346.624    0.000000      0     L
#
#     next_state next_next_state
# 0          NaN             NaN
# 1            N             NaN
# 2            N               N
# 3            N               N
# 4            N               N
# ..         ...             ...
# 227          L               L
# 228          L               L
# 229          L               L
# 230          L               L
# 231          L               L
#
# [232 rows x 8 columns]

# %%
data.tail(90)
# Out:
#                     date  Rainfall   Dam cap  WaterLevel  State state  \
# 142  1992-08-07 22:00:00    2392.6  2842.085    0.557428  18921     N
# 143  1992-12-07 23:00:00     582.0  2842.086    0.550947      0     N
# 144  1992-01-08 00:00:00      17.8  2842.087    0.544465      0     L
# 145  1992-04-08 01:00:00     245.6  2842.088    0.537983      0     L
# 146  1993-08-08 02:00:00    1823.1  2842.089    0.531501  18921     L
# ..                   ...       ...       ...         ...    ...   ...
# 227  2012-12-11 11:00:00     431.8  2171.387    0.006482      0     L
# 228  2013-01-11 12:00:00      14.9  2900.232    0.000000      0     L
# 229  2013-04-11 13:00:00     364.5  3346.624    0.000000      0     L
# 230  2013-08-11 14:00:00    2164.8  3346.624    0.000000  11087     L
# 231  2013-12-11 15:00:00     502.1  3346.624    0.000000      0     L
#
#     next_state next_next_state
# 142          N               N
# 143          N               N
# 144          N               N
# 145          L               N
# 146          L               L
# ..         ...             ...
# 227          L               L
# 228          L               L
# 229          L               L
# 230          L               L
# 231          L               L
#
# [90 rows x 8 columns]

# %%
df = pd.DataFrame(next_next_state_prob)
for i in range(df.shape[0]):
    print(i)
    df.iloc[i] = df.iloc[i]/df.iloc[i].sum()
print(df.values)
# Out:
# 0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-122-fe313c5b5f2a> in <module>
#       2 for i in range(df.shape[0]):
#       3     print(i)
# ----> 4     df.iloc[i] = df.iloc[i]/df.iloc[i].sum()
#       5 print(df.values)
#
# ~/.virtualenvs/prj-web/lib/python3.7/site-packages/pandas/core/generic.py in stat_func(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   11583             skipna=skipna,
#   11584             numeric_only=numeric_only,
# > 11585             min_count=min_count,
#   11586         )
#   11587
#
# ~/.virtualenvs/prj-web/lib/python3.7/site-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4088                 )
#    4089             with np.errstate(all="ignore"):
# -> 4090                 return op(delegate, skipna=skipna, **kwds)
#    4091
#    4092         # TODO(EA) dispatch to Index
#
# ~/.virtualenvs/prj-web/lib/python3.7/site-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      68             try:
#      69                 with np.errstate(invalid="ignore"):
# ---> 70                     return f(*args, **kwargs)
#      71             except ValueError as e:
#      72                 # we want to transform an object array
#
# ~/.virtualenvs/prj-web/lib/python3.7/site-packages/pandas/core/nanops.py in nansum(values, axis, skipna, min_count, mask)
#     500     elif is_timedelta64_dtype(dtype):
#     501         dtype_sum = np.float64
# --> 502     the_sum = values.sum(axis, dtype=dtype_sum)
#     503     the_sum = _maybe_null_out(the_sum, axis, mask, values.shape, min_count=min_count)
#     504
#
# ~/.virtualenvs/prj-web/lib/python3.7/site-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      36 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      37          initial=_NoValue, where=True):
# ---> 38     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      39
#      40 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'
